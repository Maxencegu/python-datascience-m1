# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Maxencegu/python-datascience-m1/blob/main/cours/cm01_installation_et_environnement/cm01_cours.ipynb)
#
# # **CM01 — Installation & Environnement de développement**
#
# **Python & Data Science · UPJV Amiens · M1 Économie**
#
# ---
#
# Ce premier cours magistral couvre tout ce qu'il faut mettre en place **avant d'écrire la moindre ligne de code** : installer Python, configurer VS Code, créer un projet, et comprendre les environnements virtuels et la gestion de paquets.
#
# > **Note** : les démonstrations VS Code sont réalisées **en direct** par l'enseignant. Ce notebook est votre support de référence — les commandes et explications sont ici pour que vous puissiez reproduire chaque étape chez vous.
#
# À l'issue de ce CM, vous saurez :
# - installer Python et vérifier l'installation ;
# - configurer VS Code avec les extensions essentielles ;
# - créer un projet Python structuré ;
# - exécuter un fichier `.py` de trois manières différentes ;
# - créer et activer un environnement virtuel ;
# - installer des paquets avec `pip` ;
# - utiliser le mode Python interactif (Jupyter) dans VS Code.

# %% [markdown]
# ---
# ## 1. Pourquoi Python ?
#
# Python est aujourd'hui le **langage dominant en IA et data science**. Voici pourquoi :
#
# | Avantage | Détail |
# |----------|--------|
# | **Lisible** | Se lit presque comme de l'anglais |
# | **Bibliothèques IA** | TensorFlow, PyTorch, scikit-learn, Pandas, NumPy |
# | **Standard industriel** | OpenAI, Google, Anthropic utilisent Python |
# | **Communauté** | Des millions de développeurs et ressources |
# | **Polyvalent** | Web, IA, automatisation, data science |
#
# ### Python vs Java — même tâche, moins de code

# %%
# Python : calculer une moyenne
notes = [12, 15, 18, 10, 14]
moyenne = sum(notes) / len(notes)
print(f"Moyenne : {moyenne}")
# Out:
# Moyenne : 13.8

# %% [markdown]
# ```java
# // Java : même calcul — beaucoup plus verbeux
# public class Moyenne {
#     public static void main(String[] args) {
#         int[] notes = {12, 15, 18, 10, 14};
#         int somme = 0;
#         for (int note : notes) { somme += note; }
#         double moyenne = (double) somme / notes.length;
#         System.out.println("Moyenne : " + moyenne);
#     }
# }
# ```
#
# ### Deux parties pour apprendre Python
#
# 1. **La syntaxe** — comment écrire le code. Python est simple ici, les outils IA peuvent aider.
# 2. **Le workflow** — quels outils utiliser, comment démarrer un projet, comment déboguer, comment structurer son travail. **C'est ce que la plupart des cours oublient.** Ce CM couvre entièrement cette partie.

# %% [markdown]
# ---
# ## 2. Qu'est-ce que la programmation ?
#
# Programmer, c'est **écrire des instructions étape par étape pour qu'un ordinateur les exécute**. Comme une recette de cuisine : chaque étape doit être précise et dans le bon ordre.
#
# Les ordinateurs ne comprennent que le binaire (0 et 1). Python fait le pont :
#
# ```
# Vous écrivez du Python (lisible)  →  Python traduit  →  L'ordinateur exécute
# ```
#
# ### Votre premier aperçu de Python

# %%
# Ce code est presque lisible comme de l'anglais
nom = "Alice"
age = 20
print(f"Bonjour, je m'appelle {nom} et j'ai {age} ans.")

if age >= 18:
    print("Je suis majeur.")
else:
    print("Je suis mineur.")

# %% [markdown]
# ---
# ## 3. Installer Python
#
# > **Démonstration live** — cette section est réalisée en direct. Suivez les instructions ci-dessous sur votre machine.
#
# ### 3.1 Télécharger Python
#
# Toujours télécharger depuis le site officiel : **[python.org/downloads](https://python.org/downloads)**
#
# Le site détecte votre système automatiquement et propose la dernière version stable.
#
# **Utilisez toujours Python 3** (Python 2 n'est plus supporté depuis 2020).
#
# ---
#
# ### 3.2 Installation sur Windows
#
# 1. Télécharger l'installateur depuis `python.org/downloads`
# 2. Lancer l'installateur
# 3. ⚠️ **IMPORTANT** : cocher **"Add python.exe to PATH"** en bas de la fenêtre
# 4. Cliquer **"Install Now"**
# 5. Cliquer "Close" quand vous voyez "Setup was successful"
#
# > Si vous oubliez "Add to PATH", Python ne fonctionnera pas depuis le terminal. C'est l'erreur n°1.
#
# **Vérifier l'installation** (dans le terminal Windows) :
# ```
# python --version
# ```
#
# ---
#
# ### 3.3 Installation sur macOS
#
# 1. Télécharger le fichier `.pkg` depuis `python.org/downloads`
# 2. Ouvrir le fichier et suivre les étapes (Continuer → Accepter → Installer)
# 3. Entrer votre mot de passe Mac si demandé
#
# **Vérifier l'installation** (ouvrir un nouveau Terminal) :
# ```
# python3 --version
# ```
#
# > Sur Mac, utilisez `python3` (pas `python`) pour désigner Python 3.
#
# ---
#
# ### 3.4 Tester Python en mode interactif
#
# Après installation, lancez Python directement dans le terminal :
#
# ```
# python        (Windows)
# python3       (Mac/Linux)
# ```
#
# Vous verrez `>>>` — Python attend vos instructions :
#
# ```python
# >>> print("Hello from Python!")
# Hello from Python!
# >>> exit()    # pour quitter
# ```

# %% [markdown]
# ---
# ## 4. Visual Studio Code (VS Code)
#
# > **Démonstration live** — l'enseignant installe et configure VS Code en direct.
#
# VS Code est l'éditeur de code le plus utilisé pour Python. Il est **gratuit, open-source**, et utilisé par des millions de développeurs.
#
# Les outils IA comme **Cursor** et **Windsurf** sont construits sur VS Code — tout ce que vous apprenez ici est directement transférable.
#
# ### 4.1 Télécharger VS Code
#
# **[code.visualstudio.com](https://code.visualstudio.com)**
#
# **Windows** — lors de l'installation, cocher :
# - ✅ Add "Open with Code" to Windows Explorer file context menu
# - ✅ Add "Open with Code" to Windows Explorer directory context menu
# - ✅ Register Code as an editor for supported file types
# - ✅ Add to PATH
#
# ---
#
# ### 4.2 Extensions à installer
#
# Cliquer sur l'icône Extensions dans la barre latérale gauche (4 carrés) et installer :
#
# | Extension | Éditeur | Rôle |
# |-----------|---------|------|
# | **Python** | Microsoft | Support Python de base, exécution, débogage |
# | **Pylance** | Microsoft | Complétion intelligente, détection d'erreurs |
# | **Jupyter** | Microsoft | Mode Python interactif (essentiel pour la data science) |
#
# Extensions optionnelles (qualité de vie) :
#
# | Extension | Rôle |
# |-----------|------|
# | **Atom One Dark Theme** | Thème sombre reposant pour les yeux |
# | **Material Icon Theme** | Icônes de fichiers reconnaissables |
#
# ---
#
# ### 4.3 Paramètres essentiels
#
# Ouvrir les paramètres avec `Ctrl+,` (Windows) ou `Cmd+,` (Mac) :
#
# **1. Mode interactif Jupyter**
# - Chercher : `execute selection`
# - Trouver : `Jupyter > Interactive Window > Text Editor: Execute Selection`
# - ✅ Activer
# - *Pourquoi* : `Shift+Entrée` exécutera la sélection dans une fenêtre interactive.
#
# **2. Indentation de l'arborescence**
# - Chercher : `tree indent`
# - Changer de 8 à **20** pour une arborescence plus lisible
#
# ---
#
# ### 4.4 Sélectionner l'interpréteur Python
#
# Après avoir ouvert un dossier dans VS Code :
# - `Ctrl+Shift+P` (Windows) ou `Cmd+Shift+P` (Mac)
# - Taper : `Python: Select Interpreter`
# - Choisir la version Python installée
#
# L'interpréteur actif s'affiche en bas à droite de VS Code : `Python 3.x.x`

# %% [markdown]
# ---
# ## 5. Créer un projet Python
#
# > **Démonstration live**
#
# ### 5.1 Structure de dossiers
#
# Avant de coder, créons un espace de travail organisé :
#
# ```
# Documents/
# └── PythonProjects/          ← dossier racine pour tous vos projets
#     └── python-for-ai/       ← votre premier projet (kebab-case)
#         └── python-for-ai.code-workspace
# ```
#
# **Convention de nommage** : utilisez des minuscules avec des tirets (`kebab-case`) — c'est le standard sur GitHub.
#
# ### 5.2 Ouvrir le dossier dans VS Code
#
# Trois méthodes :
# 1. **Depuis VS Code** : `Fichier > Ouvrir le dossier` → sélectionner `python-for-ai`
# 2. **Clic droit** sur le dossier → "Ouvrir avec Code"
# 3. **Terminal** : `code python-for-ai`
#
# > VS Code travaille toujours avec des **dossiers**, pas des fichiers individuels. Cela lui permet de comprendre la structure de votre projet.
#
# ### 5.3 Créer un workspace
#
# Un workspace sauvegarde les paramètres de votre projet :
# - `Fichier > Enregistrer l'espace de travail sous…`
# - Nommer : `python-for-ai.code-workspace`
# - Sauvegarder dans le dossier `python-for-ai`
#
# Double-cliquer sur ce fichier réouvre directement votre projet avec tous vos paramètres.

# %% [markdown]
# ---
# ## 6. Premier fichier Python — `hello.py`
#
# > **Démonstration live**
#
# ### 6.1 Créer le fichier
#
# Dans l'Explorateur VS Code :
# 1. Cliquer sur l'icône "Nouveau fichier" (page avec +)
# 2. Nommer : `hello.py`
# 3. Appuyer sur Entrée
#
# > L'extension `.py` est obligatoire — elle indique à VS Code et à Python que c'est un fichier Python.
#
# ### 6.2 Écrire le code

# %%
# Contenu de hello.py
print("Hello, World!")
print("J'apprends Python pour la data science.")
print("Mon nom est [Votre Prénom]")

# %% [markdown]
# ### 6.3 Exécuter le code — 3 méthodes
#
# | Méthode | Comment |
# |---------|----------|
# | **Bouton Run** | Cliquer le triangle ▶ en haut à droite |
# | **Clic droit** | Dans l'éditeur → "Exécuter le fichier Python dans le terminal" |
# | **Raccourci** | `Ctrl+F5` (Windows/Linux) ou `Cmd+F5` (Mac) |
#
# ### 6.4 Comprendre la sortie terminal
#
# ```
# cd C:\...\python-for-ai
# C:\...\python.exe hello.py
# Hello, World!
# J'apprends Python pour la data science.
# Mon nom est [Votre Prénom]
# ```
#
# Ce que fait VS Code en coulisses :
# 1. Navigue vers votre dossier projet
# 2. Exécute `python hello.py` dans le terminal
#
# Vous pouvez faire exactement la même chose manuellement :
#
# ```bash
# python hello.py         # Windows
# python3 hello.py        # Mac/Linux
# ```
#
# ### 6.5 Comment Python exécute votre code
#
# Python lit et exécute le code **de haut en bas, de gauche à droite**, ligne par ligne :
#
# ```
# Ligne 1  →  Python lit  →  Python traduit  →  Exécute  →  Affiche
# Ligne 2  →  même processus
# Ligne 3  →  même processus
# ```
#
# L'ordre compte : une ligne ne peut pas utiliser quelque chose défini plus bas.

# %%
# L'ordre d'exécution est toujours de haut en bas
print("Étape 1 : Je commence")
x = 10
print(f"Étape 2 : x vaut {x}")
x = x * 2
print(f"Étape 3 : x vaut maintenant {x}")
print("Étape 4 : Fin du programme")

# %% [markdown]
# ---
# ## 7. Environnements virtuels
#
# ### 7.1 Pourquoi un environnement virtuel ?
#
# Imaginez deux projets sur votre ordinateur :
# - **Projet A** : nécessite `pandas` version 1.5
# - **Projet B** : nécessite `pandas` version 2.0
#
# Sans environnement virtuel, impossible d'avoir les deux — une seule version peut être installée globalement.
#
# **Un environnement virtuel = une installation Python isolée par projet.** Chaque projet a ses propres paquets, ses propres versions, complètement indépendants.
#
# ```
# PythonProjects/
# ├── projet-a/
# │   ├── .venv/          ← pandas 1.5 installé ici
# │   └── script.py
# └── projet-b/
#     ├── .venv/          ← pandas 2.0 installé ici
#     └── script.py
# ```
#
# ### 7.2 Créer un environnement virtuel
#
# Dans le terminal VS Code (`` Ctrl+` ``)  :
#
# ```bash
# python -m venv .venv
# ```
#
# Cela crée un dossier `.venv` dans votre projet avec une installation Python isolée.
#
# > **Bonne nouvelle** : VS Code détecte automatiquement le `.venv` et l'active dans le terminal intégré — vous verrez `(.venv)` devant votre invite de commande.
#
# ### 7.3 Activer manuellement
#
# Si VS Code ne l'active pas automatiquement :
#
# ```bash
# # Windows
# .venv\Scripts\activate
#
# # Mac/Linux
# source .venv/bin/activate
# ```
#
# Le `(.venv)` en début de ligne confirme que l'environnement est actif.
#
# ### 7.4 Désactiver
#
# ```bash
# deactivate
# ```
#
# ### 7.5 Note sur Anaconda
#
# Vous avez peut-être entendu parler d'Anaconda — un outil qui gère aussi les environnements Python. Il est populaire en data science car il inclut beaucoup de paquets par défaut.
#
# **Recommandation** : utilisez les environnements virtuels Python natifs (`venv`). C'est plus léger, plus rapide, et c'est le standard en entreprise. N'utilisez Anaconda que si un projet ou une équipe le requiert spécifiquement.

# %% [markdown]
# ---
# ## 8. Paquets Python et pip
#
# ### 8.1 Qu'est-ce qu'un paquet ?
#
# Un paquet est du **code Python écrit par d'autres développeurs** que vous pouvez utiliser dans vos projets. Plutôt que de tout réécrire de zéro, vous réutilisez ce qui existe.
#
# Exemples de paquets essentiels :
#
# | Paquet | Utilisation |
# |--------|------------|
# | `requests` | Télécharger des données depuis le web |
# | `pandas` | Manipuler des données tabulaires |
# | `numpy` | Calculs mathématiques rapides |
# | `matplotlib` | Créer des graphiques |
# | `openai` | Connecter une application à ChatGPT |
#
# ### 8.2 pip — le gestionnaire de paquets
#
# `pip` (Pip Installs Packages) télécharge les paquets depuis **PyPI** (Python Package Index) — une bibliothèque de plus de 500 000 paquets open-source.
#
# `pip` est automatiquement inclus avec Python.
#
# ### 8.3 Commandes essentielles
#
# ```bash
# # Installer un paquet
# pip install requests
#
# # Installer une version spécifique
# pip install pandas==2.1.0
#
# # Installer plusieurs paquets
# pip install numpy matplotlib seaborn
#
# # Lister les paquets installés
# pip list
#
# # Désinstaller un paquet
# pip uninstall requests
# ```
#
# ### 8.4 Utiliser un paquet installé

# %%
# Après pip install requests, on peut l'importer et l'utiliser
import requests

reponse = requests.get("https://api.github.com")
print(f"Statut de l'API GitHub : {reponse.status_code}")
# 200 = succès

# %% [markdown]
# ### 8.5 Le fichier `requirements.txt`
#
# Pour partager votre projet, listez tous vos paquets dans un fichier `requirements.txt` :
#
# ```bash
# # Générer automatiquement la liste des paquets installés
# pip freeze > requirements.txt
# ```
#
# Contenu exemple de `requirements.txt` :
# ```
# pandas==2.1.0
# numpy==1.26.0
# matplotlib==3.8.0
# requests==2.31.0
# ```
#
# Un collègue peut recréer l'environnement identique avec :
# ```bash
# pip install -r requirements.txt
# ```
#
# ### 8.6 Méthodes d'import

# %%
# Méthode 1 : importer le module entier
import math
print(math.pi)          # 3.14159...
print(math.sqrt(16))    # 4.0

# Méthode 2 : importer une fonction spécifique
from math import pi, sqrt
print(pi)               # 3.14159...
print(sqrt(25))         # 5.0

# Méthode 3 : importer avec un alias (convention pour pandas/numpy)
import numpy as np
import pandas as pd

tableau = np.array([1, 2, 3, 4, 5])
print(tableau * 2)      # [2 4 6 8 10]

# %% [markdown]
# ---
# ## 9. Python Interactif — Le meilleur mode pour l'IA
#
# ### 9.1 Pourquoi le mode interactif ?
#
# Quand vous travaillez sur des données ou de l'IA, vous avez besoin de :
# - Tester un bout de code sans relancer tout le fichier
# - Voir les résultats immédiatement
# - Garder les variables en mémoire d'une cellule à l'autre
# - Expérimenter rapidement
#
# Le mode interactif combine le meilleur des deux mondes :
# - **Organisation** d'un fichier `.py` (pas de Jupyter Notebook désorganisé)
# - **Interactivité** de Jupyter (exécution cellule par cellule, résultats visuels)
#
# ### 9.2 Installer le kernel Jupyter
#
# ```bash
# pip install ipykernel
# ```
#
# ### 9.3 Utiliser le mode interactif dans VS Code
#
# - **Jupyter › Interactive Window › Text Editor: Execute Selection**
#
# Dans un fichier `.py`, utilisez le raccourci **`Shift+Entrée`** :
# - Sans sélection : exécute la ligne courante
# - Avec une sélection : exécute le code sélectionné
#
# Une fenêtre interactive s'ouvre à droite et affiche les résultats.
#
# ### 9.4 Délimiter des "cellules" dans un fichier `.py`
#
# Vous pouvez structurer votre fichier en cellules avec `# %%` :

# %%
# %% Cellule 1 : charger les données
import pandas as pd

data = {
    'nom': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'note': [15, 12, 18, 14],
    'ville': ['Amiens', 'Paris', 'Lyon', 'Amiens']
}
df = pd.DataFrame(data)
print(df)

# %%
# %% Cellule 2 : analyser (df est toujours en mémoire)
print(f"Nombre d'étudiants : {len(df)}")
print(f"Note moyenne : {df['note'].mean():.1f}")
print(f"Meilleure note : {df['note'].max()}")

# %%
# %% Cellule 3 : filtrer (toujours en mémoire)
amienois = df[df['ville'] == 'Amiens']
print("Étudiants d'Amiens :")
print(amienois)

# %% [markdown]
# ### 9.5 Les Jupyter Notebooks (`.ipynb`)
#
# Les notebooks Jupyter sont des fichiers `.ipynb` — c'est le format utilisé pour ce cours (les TDs).
#
# **Différences avec un fichier `.py` interactif** :
#
# | | Fichier `.py` + interactif | Notebook `.ipynb` |
# |-|---------------------------|-------------------|
# | Format | Fichier texte pur | Fichier JSON complexe |
# | Git | Facile à versionner | Diffs difficiles à lire |
# | Production | Utilisé en entreprise | Utilisé pour l'exploration |
# | Usage recommandé | Projets, scripts | Cours, exploration, présentations |
#
# Pour ce cours : les **TDs sont en `.ipynb`** (Colab), les **projets personnels seront en `.py`**.

# %% [markdown]
# ---
# ## 10. Utiliser l'IA pour apprendre plus vite
#
# Les assistants IA (ChatGPT, Claude) sont des outils très puissants pour apprendre Python. Voici comment les utiliser efficacement.
#
# ### Bons exemples de prompts
#
# ❌ **Mauvais** : *"Mon code ne marche pas, corrige-le"*
#
# ✅ **Bon** : *"J'apprends Python et j'essaie de calculer la moyenne d'une liste. Mon code : `sum(notes) / len(notes)`. Est-ce qu'il y a une façon plus efficace ?"*
#
# ### Stratégies efficaces
#
# 1. **Demander des explications** : "Explique-moi les fonctions Python simplement"
# 2. **Déboguer avec contexte** : coller le code ET le message d'erreur exact
# 3. **Demander des alternatives** : "Montre-moi 3 façons de résoudre ce problème"
# 4. **Vérifier la compréhension** : tester les suggestions et poser des questions de suivi
#
# > L'IA est un outil pour **accélérer** l'apprentissage, pas pour le remplacer. L'objectif est de **comprendre**, pas d'avoir du code qui fonctionne sans savoir pourquoi.

# %% [markdown]
# ---
# ## 11. Récapitulatif — Workflow complet
#
# Voici le workflow à suivre pour chaque nouveau projet Python :
#
# ```bash
# # 1. Créer le dossier projet
# mkdir mon-projet
# cd mon-projet
#
# # 2. Ouvrir dans VS Code
# code .
#
# # 3. Créer l'environnement virtuel
# python -m venv .venv
#
# # 4. VS Code active .venv automatiquement
# # Vérifier : (.venv) doit apparaître dans le terminal
#
# # 5. Installer les paquets nécessaires
# pip install pandas matplotlib requests
#
# # 6. Sauvegarder la liste des paquets
# pip freeze > requirements.txt
#
# # 7. Créer votre premier fichier .py et coder !
# ```
#
# ### Ce que vous savez maintenant
#
# | Concept | Ce qu'il faut retenir |
# |---------|----------------------|
# | **Python** | Télécharger depuis python.org, toujours Python 3, cocher "Add to PATH" |
# | **VS Code** | Extensions : Python + Pylance + Jupyter |
# | **Fichier `.py`** | Extension obligatoire, exécution avec bouton ▶ ou `Ctrl+F5` |
# | **Terminal intégré** | `` Ctrl+` `` pour ouvrir, `python hello.py` pour exécuter |
# | **Environnement virtuel** | `python -m venv .venv` → isoler les paquets par projet |
# | **pip** | `pip install paquet` → `pip list` → `pip freeze > requirements.txt` |
# | **Import** | `import numpy as np` ou `from math import pi` |
# | **Mode interactif** | `Shift+Entrée` dans un `.py` → résultats immédiats |
#
# ### Prochain CM
#
# **CM02 — Fondamentaux Python** : syntaxe, variables, types de données (int, float, str, bool), opérateurs. On commence à vraiment coder.
